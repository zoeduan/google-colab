# %% [markdown]
# # Generating The Meta Data and Json
#
# In the previous notebook we worked through converting our ground truth PDFs into two formats, a TEI XML and a mark down. The TEI XML will provide the structure and important meta data like titles, authors and references while the mark down will provide us with body text.
#
# The goal for this notebook will be to combine both of those files into one json file.
#
# # A Beautiful Soup
#
# To turn the raw TEI XML that GROBID produced into clean, program‑friendly metadata we’ll lean on Beautiful Soup, a lightweight Python library that makes scraped or machine generated markup feel like a native data structure. Under the hood, Beautiful Soup parses HTML or XML into a tree of Python objects; tags become nodes, attributes turn into dictionary like fields, and text sits exactly where you expect it. That means you can “walk” an XML document with intuitive commands such as find("title") or CSS style selectors like header.select("analytic > author > persName") rather than juggling fragile, low level string operations or the verbose standard library xml.etree.
#
# For our pipeline this is crucial: TEI files are verbose and deeply nested, but Beautiful Soup lets us pluck out just the bits we care about titles, author names, abstracts, reference lists then immediately cast them to JSON for downstream chunking and LLM ingestion.
#
# In short, it turns messy scholarly XML into tidy Python dicts with only a few lines of code, saving both compute time and human patience.

# %%
import json, re, glob, bs4, textwrap, hashlib
from pathlib import Path

import os, time, requests, shutil, json, re, glob, textwrap, hashlib
import xml.etree.ElementTree as ET          # still handy elsewhere
import bs4                                  # BeautifulSoup for quick XML grabs
from pathlib import Path
from google.colab import drive, files

# ────────────────────────────────────────────────────────────────
# 0.  Mount Drive & define folders
# ────────────────────────────────────────────────────────────────
drive.mount('/content/drive', force_remount=True)
base_directory = "/content/drive/MyDrive/Colab_notebooks/AI/"
PDF_DIR = base_directory+"arxiv_pdfs"   # input PDFs
OUT_XML = base_directory+"/grobid_xml"   # GROBID TEI files
OUT_MD  = base_directory+"arxiv_markdowns2"  # Nougat markdowns
# Out:
# Mounted at /content/drive

# %%
def title_author_abstract(soup: bs4.BeautifulSoup) -> dict:
    """Return title, author list, abstract string."""
    title = soup.find("title").get_text(" ")
    header = soup.find("teiHeader")
    authors = [p.get_text(" ")
               for p in header.select("analytic > author > persName")] if header else []
    abstract = soup.abstract.get_text(" ") if soup.abstract else ""
    return {"title": title, "authors": authors, "abstract": abstract}

def _clean_name(pers: bs4.Tag) -> str:
    """Build 'Firstname M. Surname' from <persName> content."""
    parts = []
    # preserve given order of forename(s) then surname
    for tag in pers.find_all(["forename", "surname"]):
        parts.append(tag.get_text(" "))
    return re.sub(r"\s+", " ", " ".join(parts)).strip()

# %%
def reference_list(soup: bs4.BeautifulSoup) -> list:
    """
    Parse <biblStruct> elements and return a list of
    {id, title, authors, year, venue, doi}.
    Handles the common GROBID patterns you showed:
      · title may live under <analytic> or <monogr>
      · authors may live in either place (or both)
      · some records have DOI / ArXiv / volume info, others don't
    """

    refs = []
    for bib in soup.find_all("biblStruct"):

        # 1‒ id (xml:id or id attribute)
        r_id = bib.get("xml:id") or bib.get("id")

        # 2‒ main title  ─────────────────────────────────────────
        title_tag = None
        if bib.analytic:
            # prefer <title type="main"> if present
            title_tag = bib.analytic.find("title", {"type": "main"}) \
                        or bib.analytic.find("title")
        if not title_tag and bib.monogr:
            title_tag = bib.monogr.find("title", {"type": "main"}) \
                        or bib.monogr.find("title")

        r_title = title_tag.get_text(" ").strip() if title_tag else ""

        # 3‒ authors  ───────────────────────────────────────────
        # search <author><persName> in analytic first, then monogr
        author_nodes = []
        if bib.analytic:
            author_nodes = bib.analytic.find_all("author")
        if not author_nodes and bib.monogr:
            author_nodes = bib.monogr.find_all("author")

        r_authors = []
        for a in author_nodes:
            p = a.find("persName")
            if p:
                r_authors.append(_clean_name(p))

        # 4‒ year  ──────────────────────────────────────────────
        date_tag = bib.find("date", {"type": "published"}) or bib.find("date")
        year = ""
        if date_tag:
            if date_tag.has_attr("when"):
                year = date_tag["when"][:4]          # "2005-07" → "2005"
            else:
                year = re.search(r"\d{4}", date_tag.get_text() or "") or ""
                year = year.group(0) if year else ""

        # 5‒ venue (monograph / journal / booktitle)  ───────────
        venue_tag = None
        if bib.monogr:
            # prefer a <title level="m">, else first monogr <title>
            venue_tag = bib.monogr.find("title", {"level": "m"}) \
                        or bib.monogr.find("title")
        r_venue = venue_tag.get_text(" ").strip() if venue_tag else ""

        # 6‒ DOI / other identifier  ────────────────────────────
        doi_tag = bib.find("idno", {"type": lambda v: v and v.lower() == "doi"})
        doi     = doi_tag.get_text().strip() if doi_tag else ""

        refs.append({
            "id"     : r_id,
            "title"  : r_title,
            "authors": r_authors,
            "year"   : year,
            "venue"  : r_venue,
            "doi"    : doi
        })

    return refs

# %%
import re, unicodedata
import bs4

# ------------------------------------------------------------------
# 1.  Normalise a heading so the TEI and markdown keys line up
# ------------------------------------------------------------------
def _norm(title: str) -> str:
    """Lower-case, strip accents & punctuation, collapse whitespace."""
    txt = unicodedata.normalize("NFKD", title)
    txt = "".join(ch for ch in txt if ch.isalnum() or ch.isspace())
    return re.sub(r"\s+", " ", txt).strip().lower()

# ------------------------------------------------------------------
# 2.  Slice the Nougat markdown into {norm_title: markdown_chunk}
# ------------------------------------------------------------------
def md_sections(md_text: str) -> dict[str, str]:
    """
    Returns {normalised_title: markdown_text_between_this_and_next_H1}.
    Assumes Nougat emits   # Title   for top-level sections.
    """
    sections = {}
    current_title, buff = None, []
    for line in md_text.splitlines():
        h = re.match(r"^#\s+(.+?)\s*$", line)
        if h:
            # flush previous
            if current_title:
                sections[_norm(current_title)] = "\n".join(buff).strip()
            current_title = h.group(1)
            buff = []          # reset buffer
        else:
            buff.append(line)
    # last section
    if current_title:
        sections[_norm(current_title)] = "\n".join(buff).strip()
    return sections

# ------------------------------------------------------------------
# 3.  Combine GROBID outline with Nougat prose
# ------------------------------------------------------------------
def combined_sections(tei_soup: bs4.BeautifulSoup, md_text: str):
    """
    Yields {'title': original_title, 'text': chosen_markdown_or_plain_text}.
    """
    md_map = md_sections(md_text)
    body = tei_soup.find("body")
    if not body:
        return []

    out = []
    for div in body.find_all("div", recursive=False):
        head = div.find("head")
        raw_title = head.get_text(" ") if head else "Untitled"
        key = _norm(raw_title)

        # remove headings so get_text() doesn't duplicate titles
        for h in div.select("head"):
            h.decompose()
        fallback_plain = " ".join(div.get_text(" ").split())

        text = md_map.get(key, fallback_plain)   # prefer Nougat; else TEI
        out.append({"title": raw_title, "text": text})
    return out

# %%
# make an output folder once
JSON_DIR = "/content/drive/MyDrive/arxiv_json"
Path(JSON_DIR).mkdir(exist_ok=True)


def pipeline_and_writeout(tei_path: Path, json_dir: Path = Path(JSON_DIR)) -> None:
    """End-to-end: parse one TEI, gather fields, dump single JSON file."""
    soup = bs4.BeautifulSoup(tei_path.read_text(), "xml")

    header_info = title_author_abstract(soup)
    refs        = reference_list(soup)
    # Nougat markdown
    md_file = Path(OUT_MD) / f"{pid}.mmd"
    if md_file.exists():
        md_text = md_file.read_text()
    else:
        print("⚠️ Nougat missing for", pid)
        md_text = ""
    sections = combined_sections(soup, md_text)

    data = {
        **header_info,
        "references": refs,
        "sections"  : sections,
    }

    out_path = JSON_DIR / f"{tei_path.stem.replace('.tei', '').replace('.grobid', '')}.json"
    with out_path.open("w", encoding="utf-8") as fh:
        json.dump(data, fh, ensure_ascii=False, indent=2)
    print(f"✅ wrote {out_path}")

# ────────────────────────────────────────────────────────────────
# 2.  Run the pipeline on every TEI file
# ────────────────────────────────────────────────────────────────
for filename in sorted(os.listdir(OUT_XML)):      # alphabetic order
    full_path = Path(os.path.join(OUT_XML, filename))   # prepend the folder path
    if full_path.name.endswith(".xml"): # ignore the .txt (and any other non-XML)
      pipeline_and_writeout(Path(full_path))              # or print(filename) for names only

print("🎉  All papers processed!")
# Out:
# 🎉  All papers processed!

# %%
xfor filename in sorted(os.listdir(OUT_XML)):      # alphabetic order
    full_path = os.path.join(OUT_XML, filename)   # prepend the folder path
    if os.path.isfile(full_path):                 # skip sub-folders if any
        print(full_path)                          # or print(filename) for names only
# Out:
# /content/drive/MyDrive/grobid_xml/1911.09661v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2102.02503v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2112.02969v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2201.11903v6.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2207.08982v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2210.10723v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2210.11630v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2211.02069v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2211.04715v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2212.09196v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2212.09271v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2212.09420v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2301.13820v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2302.00093v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2302.03491v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2302.11957v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2302.12834v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2302.13681v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2303.00077v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2303.02155v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2303.07103v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2303.07304v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2303.15324v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2303.17513v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2304.02015v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2304.04309v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2304.06186v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2304.14354v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.01555v4.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.03025v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.03380v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.04369v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.10263v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.10645v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.12152v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2305.12907v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.01061v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.03856v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.03917v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.07195v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.09169v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.12255v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2306.14457v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.01137v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.05162v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.05722v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.05782v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.06794v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.06844v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.10169v1_408.txt
# /content/drive/MyDrive/grobid_xml/2307.10549v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.10793v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.12701v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.13221v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.15311v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.15717v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2307.16699v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.00073v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.00683v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.01776v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.02432v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.02678v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.07411v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.08061v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.10053v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.10173v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.10252v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.12247v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.15047v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.15851v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2308.16118v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.00254v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.01431v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.01868v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.04704v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.06589v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.07172v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.11852v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.12732v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2309.17072v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.00637v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.01581v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.03710v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.05149v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.06003v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.06254v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.08669v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.08842v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.09755v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.10049v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.11158v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.11237v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.12321v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.14542v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.16111v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2310.17589v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.00272v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.03837v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.07692v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.09216v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.09410v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.10791v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.10932v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2311.14876v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.00554v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.01090v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.08027v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.08642v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.12404v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.14203v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.14504v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.16132v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2312.16171v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2401.04155v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2401.04592v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2401.08683v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2401.11255v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2401.11401v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.01495v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.05130v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.06116v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.07536v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.07950v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.09579v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2402.12405v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.00807v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.00810v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.02164v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.08211v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.09599v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.11152v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.13553v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.15230v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.15673v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.18205v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2403.18405v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.02491v4.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.04925v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.07544v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.07922v6.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.09593v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.11216v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.15660v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2404.17000v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2405.07348v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2405.08848v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2405.11265v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2405.13015v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2405.15628v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2405.18774v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.01749v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.01893v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.06962v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.13138v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.14171v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.14757v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.16167v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.17873v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.18122v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2406.18134v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2407.00436v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2407.05786v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2407.10020v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2407.15716v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2408.03119v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2408.12141v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2409.03031v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2409.13980v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2409.18548v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2409.18943v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2410.01240v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2410.08993v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2410.12174v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2410.16843v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2410.16917v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2410.22108v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2411.00897v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2411.01195v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2411.06101v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2411.18583v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2411.19275v3.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2412.00471v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2412.10291v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2412.12201v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2412.15634v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2501.00562v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2501.06286v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2501.09653v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2501.17549v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2501.18954v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2502.01754v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2502.09797v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2502.11528v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2502.20503v2.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2503.01887v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2503.04413v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2503.07215v1.grobid.tei.xml
# /content/drive/MyDrive/grobid_xml/2503.13401v1.grobid.tei.xml
